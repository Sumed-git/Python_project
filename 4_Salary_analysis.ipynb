# %% [markdown]
# # Salary paid to the Analyst based on skills
#
# ### Methodology
#
# 1. Evaluate median salary
# 2. Median salary per skill
# 3. Visualize for highest paying skills

# %%
#import libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# Load Dataset
dataset = load_dataset('Sumedchakma/jobs_record')
df = dataset['train'].to_pandas()

#Data Cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df['job_skills'] = df['job_skills'].apply(
    lambda x: ast.literal_eval(x) if pd.notna(x) else x
)
# Out:
# jobs_record.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]
